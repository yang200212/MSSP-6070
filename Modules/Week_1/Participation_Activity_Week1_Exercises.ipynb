# %% [markdown]
# # Coding exercises
# Exercises 1-3 are thought exercises that don't require coding.
#
# 1. Explore the Jupyter Lab interface and look at some of the shortcuts available. Don't worry about memorizing them now (eventually they will become second nature and save you a lot of time), just get comfortable using notebooks.
#
# 2. Are all data normally distributed?
#
# 3. When would it make more sense to use the median instead of the mean for the measure of center?

# %% [markdown]
# Answers to question 2 and 3:
#
# 2. Not all data are normally distributed. In fact, I think most of the data that are generated naturally in this world are skewed at some level. For example, the overall income level in the United States would be right-skewed because most people are in the low to middle income range. I believe this is the same for education level, number of children in the family, etc.
#
# 3. When the dataset has some extreme values, or outliers, it would make more sense to use the median instead of mean to measure center.

# %% [markdown]
# ## Exercise 4: Generate the data by running this cell
# This will give you a list of numbers to work with in the remaining exercises.

# %%
import random
random.seed(0)
salaries = [round(random.random()*1000000, -3) for _ in range(100)]
print(list(salaries))
# Out:
# [844000.0, 758000.0, 421000.0, 259000.0, 511000.0, 405000.0, 784000.0, 303000.0, 477000.0, 583000.0, 908000.0, 505000.0, 282000.0, 756000.0, 618000.0, 251000.0, 910000.0, 983000.0, 810000.0, 902000.0, 310000.0, 730000.0, 899000.0, 684000.0, 472000.0, 101000.0, 434000.0, 611000.0, 913000.0, 967000.0, 477000.0, 865000.0, 260000.0, 805000.0, 549000.0, 14000.0, 720000.0, 399000.0, 825000.0, 668000.0, 1000.0, 494000.0, 868000.0, 244000.0, 325000.0, 870000.0, 191000.0, 568000.0, 239000.0, 968000.0, 803000.0, 448000.0, 80000.0, 320000.0, 508000.0, 933000.0, 109000.0, 551000.0, 707000.0, 547000.0, 814000.0, 540000.0, 964000.0, 603000.0, 588000.0, 445000.0, 596000.0, 385000.0, 576000.0, 290000.0, 189000.0, 187000.0, 613000.0, 657000.0, 477000.0, 90000.0, 758000.0, 877000.0, 923000.0, 842000.0, 898000.0, 923000.0, 541000.0, 391000.0, 705000.0, 276000.0, 812000.0, 849000.0, 895000.0, 590000.0, 950000.0, 580000.0, 451000.0, 660000.0, 996000.0, 917000.0, 793000.0, 82000.0, 613000.0, 486000.0]

# %% [markdown]
# ## Exercise 5: Calculating statistics and verifying
#
# Use the data generated above to calulate in code the following statistics without importing the statistics module. Then use the statistics module to verify your results.  Import the statistics module from https://docs.python.org/3/library/statistics.html
#
# ### mean

# %%
from statistics import median
from math import isnan
from itertools import filterfalse
import numpy as np

# %%
# Calculate mean without importing statistics module
sum_salaries = sum(salaries)
sum_salaries
mean_salaries = sum_salaries/100
mean_salaries
# Out:
# 585690.0

# %%
# Verify using the statistics module
mean_salaries = np.mean(salaries)
mean_salaries
# Out:
# np.float64(585690.0)

# %% [markdown]
# ### median

# %%
np.median(salaries)
# Out:
# np.float64(589000.0)

# %% [markdown]
# ### mode

# %%
from statistics import mode
mode(salaries)
# Out:
# 477000.0

# %% [markdown]
# ### sample variance
# Remember to use Bessel's correction.

# %% [markdown]
# I will use this formula to calculate the sample variance of salaries:
# $$s^2 = \frac{\sum_{1}^{n} (x_i - \bar{x})^2}{n - 1}$$

# %%
import statistics
statistics.variance(salaries)
# Out:
# 70664054444.44444

# %% [markdown]
# ### sample standard deviation
# Remember to use Bessel's correction.

# %% [markdown]
# I will use this formula to calculate the sample standard deviation of salaries:
# $$s = \sqrt{\frac{\sum_{1}^{n} (x_i - \bar{x})^2}{n - 1}} = \sqrt{s^2}$$

# %%
s = statistics.stdev(salaries)
s
# Out:
# 265827.11382484

# %% [markdown]
# ## Exercise 6: Calculating more statistics
# ### range

# %%
# Use the maximum value of 'salaries' to substract the minimum value of 'salaries' to get range.
salaries_range = max(salaries) - min(salaries)
salaries_range
# Out:
# 995000.0

# %% [markdown]
# ### coefficient of variation

# %%
# Coefficient of variation equals the unitless ratio of standard deviation to the mean:
coef_var = s/x
coef_var
# Out:
# np.float64(0.45386998894439035)

# %% [markdown]
# ### interquartile range

# %%
statistics.quantiles(salaries, n=4, method='inclusive')
# By this function quantiles() I know that q1 is 403500, and q3 is 816750. I name the interquartile range to IQR, and then calculate IQR to be q3-q1.
IQR = 816750-403500
IQR
# Out:
# 413250

# %%
# By consulting ChatGPT, I know that I can also use the iqr() function by importing the Scipy package:
from scipy.stats import iqr
iqr(salaries)
# Out:
# np.float64(413250.0)

# %% [markdown]
# ### quartile coefficent of dispersion

# %%
# the quantile coefficient of dispersion can be calculated by (q3-q1)/(q3+q1)
QCD = IQR/(403500+816750)
QCD
# Out:
# 0.338660110633067

# %% [markdown]
# ## Exercise 7: Scaling data
# ### min-max scaling

# %%
# By using min-max scaling, I can convert the original units of all values from 'salaries' into a common scale.
min = min(salaries)
max = max(salaries)
salaries_scaled = [(value - min) / (max - min) for value in salaries]
print(salaries_scaled)
# Out:
# [0.8472361809045226, 0.7608040201005025, 0.4221105527638191, 0.2592964824120603, 0.5125628140703518, 0.40603015075376886, 0.7869346733668342, 0.3035175879396985, 0.47839195979899496, 0.5849246231155779, 0.9115577889447236, 0.5065326633165829, 0.28241206030150756, 0.7587939698492462, 0.6201005025125628, 0.25125628140703515, 0.91356783919598, 0.9869346733668342, 0.8130653266331658, 0.9055276381909547, 0.31055276381909547, 0.7326633165829146, 0.9025125628140703, 0.6864321608040201, 0.4733668341708543, 0.10050251256281408, 0.43517587939698493, 0.6130653266331658, 0.9165829145728643, 0.9708542713567839, 0.47839195979899496, 0.8683417085427135, 0.26030150753768844, 0.8080402010050252, 0.5507537688442211, 0.01306532663316583, 0.7226130653266332, 0.4, 0.828140703517588, 0.6703517587939698, 0.0, 0.49547738693467336, 0.871356783919598, 0.2442211055276382, 0.3256281407035176, 0.8733668341708543, 0.19095477386934673, 0.5698492462311557, 0.23919597989949748, 0.9718592964824121, 0.8060301507537688
# ...

# %% [markdown]
# ### standardizing

# %%
# I can calculate z-score to standardize all data from 'salaries'.
z_score = [(value - x) / s for value in salaries]
z_score
# Out:
# [np.float64(0.9717217942267801),
#  np.float64(0.6482032533127501),
#  np.float64(-0.6195380058503674),
#  np.float64(-1.228956652688424),
#  np.float64(-0.28097209094033604),
#  np.float64(-0.6797275018343729),
#  np.float64(0.7460111842867592),
#  np.float64(-1.0634355387324086),
#  np.float64(-0.40887476990634786),
#  np.float64(-0.010119359012310937),
#  np.float64(1.2124797781628023),
#  np.float64(-0.3035431519343381),
#  np.float64(-1.142434252211416),
#  np.float64(0.6406795663147493),
#  np.float64(0.12154516345270126),
#  np.float64(-1.2590514006804265),
#  np.float64(1.220003465160803),
#  np.float64(1.4946180405878284),
#  np.float64(0.8438191152607681),
#  np.float64(1.1899087171688003),
#  np.float64(-1.037102634239406),
#  np.float64(0.5428716353407403),
#  np.float64(1.178623186671799),
#  np.float64(0.36982683438672426),
#  np.float64(-0.4276839874013496),
#  np.float64(-1.8233279255304788),
#  np.float64(-0.5706340403633628),
#  np.float64(0.09521225895969881),
# ...

# %% [markdown]
# ## Exercise 8: Calculating covariance and correlation
# ### covariance

# %%
salaries_cov = np.cov(salaries_scaled, z_score)
salaries_cov
# Out:
# array([[0.07137603, 0.26716293],
#        [0.26716293, 1.        ]])

# %% [markdown]
# ### Pearson correlation coefficient ($\rho$)

# %% [markdown]
# I will use this formula to calculate Pearson correlation coefficient:
# $$\rho_{X, Y} = \frac{cov(X, Y)}{s_X s_Y}$$

# %%
# Because the output of Pearson correlation coefficient shouldn't be a matrix,
# instead, it should be a single number, I looked up the calculation method of Pearson correlation coefficient
# online to correct my answer. Turns out that I should only use the value on the first row, second column of
# salaries_cov to calculate this coefficient.
cov_xy = salaries_cov[0, 1]
scaled_std = statistics.stdev(salaries_scaled)
standardized_std = statistics.stdev(z_score)
salaries_pearson = cov_xy / (scaled_std * standardized_std)
salaries_pearson
# Out:
# np.float64(1.0000000000000004)
